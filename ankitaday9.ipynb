# %%
# pandas topic##  #use for data manuplacation,data analysis, data preprocessing
import pandas as pd
import numpy as np

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data = pd.Series([1,2,3,4,5],index = ["a","b","c","d","e"])
data
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data.name = "Numbers"

# %%
data.size
# Out:
# 5

# %%
data.shape
# Out:
# (5,)

# %%
data.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
data["a"]
# Out:
# np.int64(1)

# %%
data["b"]
# Out:
# np.int64(2)

# %%
data.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
data.loc["a"],data.iloc[3]
# Out:
# (np.int64(1), np.int64(4))

# %%
data.loc["a"::2],data.iloc[3] # (method1)
# Out:
# (a    1
#  c    3
#  e    5
#  Name: Numbers, dtype: int64,
#  np.int64(4))

# %%
data.loc[["a","c","e"]],data.iloc[3]  #(method2 both we can use)
# Out:
# (a    1
#  c    3
#  e    5
#  Name: Numbers, dtype: int64,
#  np.int64(4))

# %%
#Dataframes topic##

# %%
dictionary = {
    "usn": ["3BK22CS006","3BK22CS040","3BK22CS044","3BK22CS043"],
    "name": ["ANKITA","SADHANA","SAKSHI","BHAGYA"],
    "age":  [21,20,24,22],
    "branch": ["CSE","CS","CSE","AI"]
}

# %%
df = pd.DataFrame(dictionary)
df
# Out:
#           usn     name  age branch
# 0  3BK22CS006   ANKITA   21    CSE
# 1  3BK22CS040  SADHANA   20     CS
# 2  3BK22CS044   SAKSHI   24    CSE
# 3  3BK22CS043   BHAGYA   22     AI

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8631072f-95bd-40cd-93aa-74da34fc429d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8631072f-95bd-40cd-93aa-74da34fc429d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data = pd.read_csv("sample (2).csv")
data
# Out:
#     Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 0            0    101    Ram         IT   25   50000           2  2021-01-15
# 1            1    102  Shyam         HR   30   45000           5  2019-03-10
# 2            2    103  Geeta    Finance   28   60000           4  2020-07-22
# 3            3    104  Anita         IT   35   75000          10  2015-09-30
# 4            4    105  Kiran         HR   32   52000           7  2018-06-12
# 5            5    106   John    Finance   29   58000           3  2021-11-05
# 6            6    107  Meena         IT   41   82000          15  2010-04-18
# 7            7    108  David         HR   26   48000           2  2022-02-14
# 8            8    109   Sara    Finance   38   61000          12  2013-12-01
# 9            9    110  Arjun         IT   27   54000           4  2020-08-19
# 10          10    111   Ravi         HR   33   47000           6  2017-05-23
# ...

# %%
data.head(10)    #it takes first 10 #
# Out:
#    Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 0           0    101    Ram         IT   25   50000           2  2021-01-15
# 1           1    102  Shyam         HR   30   45000           5  2019-03-10
# 2           2    103  Geeta    Finance   28   60000           4  2020-07-22
# 3           3    104  Anita         IT   35   75000          10  2015-09-30
# 4           4    105  Kiran         HR   32   52000           7  2018-06-12
# 5           5    106   John    Finance   29   58000           3  2021-11-05
# 6           6    107  Meena         IT   41   82000          15  2010-04-18
# 7           7    108  David         HR   26   48000           2  2022-02-14
# 8           8    109   Sara    Finance   38   61000          12  2013-12-01
# 9           9    110  Arjun         IT   27   54000           4  2020-08-19
#
#         City  PerformanceScore
# 0  Bangalore               4.5
# 1     Mumbai               3.8
# 2      Delhi               4.2
# ...

# %%
data.tail()  #it takes last 5 colomn
# Out:
#     Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 15          15    116   Neha         IT   40   88000          14  2011-10-21
# 16          16    117   Amit         HR   34   53000           8  2016-04-05
# 17          17    118  Pooja    Finance   30   57000           6  2018-12-12
# 18          18    119  Rahul         IT   28   56000           4  2020-02-28
# 19          19    120  Divya         HR   37   49500           9  2015-06-30
#
#          City  PerformanceScore
# 15  Bangalore               4.7
# 16     Mumbai               4.0
# 17      Delhi               4.1
# 18  Bangalore               3.9
# 19     Mumbai               4.3

# %%
data.describe() ##
# Out:
#        Unnamed: 0      EmpID        Age        Salary  Experience  \
# count    20.00000   20.00000  20.000000     20.000000   20.000000
# mean      9.50000  110.50000  32.700000  59875.000000    7.400000
# std       5.91608    5.91608   5.449288  13388.796377    4.615762
# min       0.00000  101.00000  25.000000  45000.000000    2.000000
# 25%       4.75000  105.75000  28.750000  50750.000000    4.000000
# 50%       9.50000  110.50000  31.500000  56500.000000    6.000000
# 75%      14.25000  115.25000  36.250000  61250.000000   10.250000
# max      19.00000  120.00000  45.000000  90000.000000   18.000000
#
#        PerformanceScore
# count         20.000000
# mean           4.190000
# std            0.415363
# min            3.500000
# 25%            3.900000
# 50%            4.150000
# 75%            4.425000
# max            4.900000

# %%
data.info() #for information #
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20 non-null     int64
#  1   EmpID             20 non-null     int64
#  2   Name              20 non-null     object
#  3   Department        20 non-null     object
#  4   Age               20 non-null     int64
#  5   Salary            20 non-null     int64
#  6   Experience        20 non-null     int64
#  7   JoiningDate       20 non-null     object
#  8   City              20 non-null     object
#  9   PerformanceScore  20 non-null     float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 1.7+ KB

# %%
data.shape # rows and coloum #
# Out:
# (20, 10)

# %%
data.sample() ##it take one sample data ##
# Out:
#    Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 9           9    110  Arjun         IT   27   54000           4  2020-08-19
#
#         City  PerformanceScore
# 9  Bangalore               4.0

# %%
data.Name
# Out:
# 0       Ram
# 1     Shyam
# 2     Geeta
# 3     Anita
# 4     Kiran
# 5      John
# 6     Meena
# 7     David
# 8      Sara
# 9     Arjun
# 10     Ravi
# 11    Priya
# 12    Kunal
# 13    Sneha
# 14    Vijay
# 15     Neha
# 16     Amit
# 17    Pooja
# 18    Rahul
# 19    Divya
# Name: Name, dtype: object

# %%
data[["Name","Department", "Salary"]]
# Out:
#      Name Department  Salary
# 0     Ram         IT   50000
# 1   Shyam         HR   45000
# 2   Geeta    Finance   60000
# 3   Anita         IT   75000
# 4   Kiran         HR   52000
# 5    John    Finance   58000
# 6   Meena         IT   82000
# 7   David         HR   48000
# 8    Sara    Finance   61000
# 9   Arjun         IT   54000
# 10   Ravi         HR   47000
# 11  Priya    Finance   59000
# 12  Kunal         IT   90000
# 13  Sneha         HR   51000
# 14  Vijay    Finance   62000
# 15   Neha         IT   88000
# 16   Amit         HR   53000
# 17  Pooja    Finance   57000
# 18  Rahul         IT   56000
# 19  Divya         HR   49500

# %%
data[["Name","Department", "Salary"]].head(2)
# Out:
#     Name Department  Salary
# 0    Ram         IT   50000
# 1  Shyam         HR   45000

# %%
data[["Name","Department", "Salary"]].head(6)
# Out:
#     Name Department  Salary
# 0    Ram         IT   50000
# 1  Shyam         HR   45000
# 2  Geeta    Finance   60000
# 3  Anita         IT   75000
# 4  Kiran         HR   52000
# 5   John    Finance   58000

# %%
#task1 day9#

# %%
import pandas as pd

products = pd.Series(
    data=[700, 150, 300],
    index=['Laptop', 'Mouse', 'Keyboard']
)
laptop_price = products['Laptop']

first_two = products.iloc[:2]

print("Full Series:")
print(products)

print("\nPrice of Laptop:")
print(laptop_price)

print("\nFirst two products:")
print(first_two)
# Out:
# Full Series:
# Laptop      700
# Mouse       150
# Keyboard    300
# dtype: int64
#
# Price of Laptop:
# 700
#
# First two products:
# Laptop    700
# Mouse     150
# dtype: int64

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d12374b1-4b6a-4aed-8f14-916ee570a0d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d12374b1-4b6a-4aed-8f14-916ee570a0d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data = pd.read_csv("test2.csv")
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# Name          0
# Age           1
# Department    0
# Salary        1
# dtype: int64

# %%
data.isnull()
# Out:
#    Unnamed: 0   Name    Age  Department  Salary
# 0       False  False  False       False   False
# 1       False  False  False       False   False
# 2       False  False  False       False   False
# 3       False  False   True       False   False
# 4       False  False  False       False    True
# 5       False  False  False       False   False

# %%
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
data.loc[ : ,"Name":"Department"]
# Out:
#       Name   Age Department
# 0    Alice  25.0         HR
# 1      Bob  30.0         IT
# 2  Charlie  35.0    Finance
# 3    David   NaN         IT
# 4      Eve  29.0         HR
# 5    Alice  25.0         HR

# %%
data.loc[ : ,"Name":"Salary"]
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
data.loc[ "0" : "1": ,"Name":"Department"]
# Out:
#     Name   Age Department
# 0  Alice  25.0         HR
# 1    Bob  30.0         IT

# %%
data.loc[ "1" : "3": ,"Name":"Department"]
# Out:
#       Name   Age Department
# 1      Bob  30.0         IT
# 2  Charlie  35.0    Finance
# 3    David   NaN         IT

# %%
data.iloc[1:4,1:4]
# Out:
#       Name   Age Department
# 1      Bob  30.0         IT
# 2  Charlie  35.0    Finance
# 3    David   NaN         IT

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
data.rename(columns={"Name":"N","Age":"A","Department":"D","Salary":"S"},inplace=True)

# %%
data
# Out:
#    Unnamed: 0        N     A        D        S
# 0           0    Alice  25.0       HR  50000.0
# 1           1      Bob  30.0       IT  60000.0
# 2           2  Charlie  35.0  Finance  70000.0
# 3           3    David   NaN       IT  62000.0
# 4           4      Eve  29.0       HR      NaN
# 5           5    Alice  25.0       HR  50000.0

# %%
data.drop("Unnamed: 0",axis=1,inplace=True) #use for delete the unwanted coloum here we droped the unwanted colomn      [axis=0(rows),axis=1(colomn)]

# %%
data
# Out:
#          N     A        D        S
# 0    Alice  25.0       HR  50000.0
# 1      Bob  30.0       IT  60000.0
# 2  Charlie  35.0  Finance  70000.0
# 3    David   NaN       IT  62000.0
# 4      Eve  29.0       HR      NaN
# 5    Alice  25.0       HR  50000.0

# %%
data.drop(3,axis=0,inplace=True)      # we droped the david  by using axis=0 #

# %%
data
# Out:
#          N     A        D        S
# 0    Alice  25.0       HR  50000.0
# 1      Bob  30.0       IT  60000.0
# 2  Charlie  35.0  Finance  70000.0
# 4      Eve  29.0       HR      NaN
# 5    Alice  25.0       HR  50000.0

# %%
data["update_salary"]=data["S"]+5000 # updated the salary by 5000 in each row

# %%
data
# Out:
#          N     A        D        S  update_salary
# 0    Alice  25.0       HR  50000.0        55000.0
# 1      Bob  30.0       IT  60000.0        65000.0
# 2  Charlie  35.0  Finance  70000.0        75000.0
# 4      Eve  29.0       HR      NaN            NaN
# 5    Alice  25.0       HR  50000.0        55000.0

# %%
data["update_salary3"]=data["S"].map(lambda x:x+10000)
data
# Out:
#          N     A        D        S  update_salary  update_salary2  \
# 0    Alice  25.0       HR  50000.0        60000.0         60000.0
# 1      Bob  30.0       IT  60000.0        70000.0         70000.0
# 2  Charlie  35.0  Finance  70000.0        80000.0         80000.0
# 4      Eve  29.0       HR      NaN            NaN             NaN
# 5    Alice  25.0       HR  50000.0        60000.0         60000.0
#
#    update_salary3
# 0         60000.0
# 1         70000.0
# 2         80000.0
# 4             NaN
# 5         60000.0

# %%
data.dropna()
# Out:
#          N     A        D        S  update_salary  update_salary2  \
# 0    Alice  25.0       HR  50000.0        60000.0         60000.0
# 1      Bob  30.0       IT  60000.0        70000.0         70000.0
# 2  Charlie  35.0  Finance  70000.0        80000.0         80000.0
# 5    Alice  25.0       HR  50000.0        60000.0         60000.0
#
#    update_salary3
# 0         60000.0
# 1         70000.0
# 2         80000.0
# 5         60000.0

# %%
data["A"] = data["A"].astype("int")
data.head()
# Out:
#          N   A        D        S  update_salary  update_salary2  \
# 0    Alice  25       HR  50000.0        60000.0         60000.0
# 1      Bob  30       IT  60000.0        70000.0         70000.0
# 2  Charlie  35  Finance  70000.0        80000.0         80000.0
# 4      Eve  29       HR      NaN            NaN             NaN
# 5    Alice  25       HR  50000.0        60000.0         60000.0
#
#    update_salary3
# 0         60000.0
# 1         70000.0
# 2         80000.0
# 4             NaN
# 5         60000.0

# %%
data["A"]>25
# Out:
# 0    False
# 1     True
# 2     True
# 4     True
# 5    False
# Name: A, dtype: bool

# %%
data[data["A"]>25]
# Out:
#          N   A        D        S  update_salary  update_salary2  \
# 1      Bob  30       IT  60000.0        70000.0         70000.0
# 2  Charlie  35  Finance  70000.0        80000.0         80000.0
# 4      Eve  29       HR      NaN            NaN             NaN
#
#    update_salary3
# 1         70000.0
# 2         80000.0
# 4             NaN

# %%
data.dropna(inplace=True)
data
# Out:
#          N   A        D        S  update_salary  update_salary2  \
# 0    Alice  25       HR  50000.0        60000.0         60000.0
# 1      Bob  30       IT  60000.0        70000.0         70000.0
# 2  Charlie  35  Finance  70000.0        80000.0         80000.0
# 5    Alice  25       HR  50000.0        60000.0         60000.0
#
#    update_salary3
# 0         60000.0
# 1         70000.0
# 2         80000.0
# 5         60000.0

# %%
data["A"] = data["A"].astype("int64")
data
# Out:
#          N   A        D        S  update_salary  update_salary2  \
# 0    Alice  25       HR  50000.0        60000.0         60000.0
# 1      Bob  30       IT  60000.0        70000.0         70000.0
# 2  Charlie  35  Finance  70000.0        80000.0         80000.0
# 5    Alice  25       HR  50000.0        60000.0         60000.0
#
#    update_salary3
# 0         60000.0
# 1         70000.0
# 2         80000.0
# 5         60000.0

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6d922d21-ad0d-4b59-941e-23cb2899e4de" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d922d21-ad0d-4b59-941e-23cb2899e4de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data = pd.read_csv("test2 (1).csv")
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
data["Age"] = data["Age"].fillna(value=data["Age"].mean())
data["Salary"] = data["Salary"].fillna(value=data["Salary"].mean())
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  28.8         IT  62000.0
# 4           4      Eve  29.0         HR  58400.0
# 5           5    Alice  25.0         HR  50000.0

# %%
data.Age.ffill()
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    28.8
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64
